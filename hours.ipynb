# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\miran\Downloads\MACHINE-LEARNING-FEB-2025-main\MACHINE-LEARNING-FEB-2025-main\Andulisa\df_Hours.csv')

# %%
df.head()
# Out:
#   ShortName  OrganizationKey                       Staff_name DoctorID  \
# 0       HJH                1           Hatem Hemdan Elalwanii   1_9746
# 1       HJH                1           Raghda Abdelhamid Okda   1_9864
# 2       HJH                1  Thowaiba Ahmed Eltayeb Mohammed  1_10960
# 3       HJH                1        Dalenda Mohamed Alarfaoui   1_9906
# 4       HJH                1       Elsayed Ibrahim M. Shaheen   1_4946
#
#            Specialty Specialty_Key        UnifiedSpec     DoctorClinicID  \
# 0  Internal Medicine          1_11  Internal medicine   3306974620231029
# 1    Dental Services           1_4             Dental   3304986420240301
# 2  Internal Medicine          1_11  Internal medicine  32091096020210711
# 3  Internal Medicine          1_11  Internal medicine   3287990620230710
# 4        Orthopedics          1_21        Orthopedics   1131494620211224
#
#    StartDate_DailyClinic  EndDate_DailyClinic ActualStartTime ActualEndTime  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108715 entries, 0 to 108714
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ShortName              108715 non-null  object
#  1   OrganizationKey        108715 non-null  int64
#  2   Staff_name             108381 non-null  object
#  3   DoctorID               108392 non-null  object
#  4   Specialty              108381 non-null  object
#  5   Specialty_Key          108033 non-null  object
#  6   UnifiedSpec            103703 non-null  object
#  7   DoctorClinicID         108715 non-null  int64
#  8   StartDate_DailyClinic  108715 non-null  int64
#  9   EndDate_DailyClinic    108715 non-null  int64
#  10  ActualStartTime        108715 non-null  object
#  11  ActualEndTime          108715 non-null  object
#  12  No_of_Clinic           108715 non-null  int64
#  13  No_Of_Actual_Slots     108715 non-null  int64
# ...

# %%
df['ActualStartTime'] = pd.to_timedelta(df['ActualStartTime'])
df['ActualEndTime'] = pd.to_timedelta(df['ActualEndTime'])

# %%
df['StartDate_DailyClinic'] = pd.to_datetime(df['StartDate_DailyClinic'])

# %%
df.drop(labels=['UnifiedSpec', 'PlannedWorkingHours', 'No_Of_Actual_Slots'], axis=1, inplace=True, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108715 entries, 0 to 108714
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ShortName              108715 non-null  object
#  1   OrganizationKey        108715 non-null  int64
#  2   Staff_name             108381 non-null  object
#  3   DoctorID               108392 non-null  object
#  4   Specialty              108381 non-null  object
#  5   Specialty_Key          108033 non-null  object
#  6   DoctorClinicID         108715 non-null  int64
#  7   StartDate_DailyClinic  108715 non-null  datetime64[ns]
#  8   EndDate_DailyClinic    108715 non-null  int64
#  9   ActualStartTime        108715 non-null  timedelta64[ns]
#  10  ActualEndTime          108715 non-null  timedelta64[ns]
#  11  No_of_Clinic           108715 non-null  int64
#  12  ActualWorkingHours     108715 non-null  float64
# ...

# %%
df['EndDate_DailyClinic'] = pd.to_datetime(df['EndDate_DailyClinic'])

# %%
df.head()
# Out:
#   ShortName  OrganizationKey                       Staff_name DoctorID  \
# 0       HJH                1           Hatem Hemdan Elalwanii   1_9746
# 1       HJH                1           Raghda Abdelhamid Okda   1_9864
# 2       HJH                1  Thowaiba Ahmed Eltayeb Mohammed  1_10960
# 3       HJH                1        Dalenda Mohamed Alarfaoui   1_9906
# 4       HJH                1       Elsayed Ibrahim M. Shaheen   1_4946
#
#            Specialty Specialty_Key     DoctorClinicID  \
# 0  Internal Medicine          1_11   3306974620231029
# 1    Dental Services           1_4   3304986420240301
# 2  Internal Medicine          1_11  32091096020210711
# 3  Internal Medicine          1_11   3287990620230710
# 4        Orthopedics          1_21   1131494620211224
#
#           StartDate_DailyClinic           EndDate_DailyClinic ActualStartTime  \
# 0 1970-01-01 00:00:00.020241031 1970-01-01 00:00:00.020241031 0 days 16:39:00
# ...

# %%
df.isnull().sum()
# Out:
# ShortName                   0
# OrganizationKey             0
# Staff_name                334
# DoctorID                  323
# Specialty                 334
# Specialty_Key             682
# DoctorClinicID              0
# StartDate_DailyClinic       0
# EndDate_DailyClinic         0
# ActualStartTime             0
# ActualEndTime               0
# No_of_Clinic                0
# ActualWorkingHours          0
# Sub_Specialty            2053
# dtype: int64

# %%
df = df.dropna(subset=['DoctorID', 'Staff_name', 'Specialty','Specialty_Key'], how='all')

# %%
df.isnull().sum()
# Out:
# ShortName                   0
# OrganizationKey             0
# Staff_name                 11
# DoctorID                    0
# Specialty                  11
# Specialty_Key             359
# DoctorClinicID              0
# StartDate_DailyClinic       0
# EndDate_DailyClinic         0
# ActualStartTime             0
# ActualEndTime               0
# No_of_Clinic                0
# ActualWorkingHours          0
# Sub_Specialty            1730
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ShortName                   0
# OrganizationKey             0
# Staff_name                 11
# DoctorID                    0
# Specialty                  11
# Specialty_Key             359
# DoctorClinicID              0
# StartDate_DailyClinic       0
# EndDate_DailyClinic         0
# ActualStartTime             0
# ActualEndTime               0
# No_of_Clinic                0
# ActualWorkingHours          0
# Sub_Specialty            1730
# dtype: int64

# %% [markdown]
# dah m3mha specialty el 7nst5dmo

# %%
# Find rows where DoctorID is null
null_doctorid = df[df['DoctorID'].isnull()]

# Find rows where Staff_name is null
null_staffname = df[df['Staff_name'].isnull()]

# Print summary counts
print(f"Number of rows with missing DoctorID: {len(null_doctorid)}")
print(f"Number of rows with missing Staff_name: {len(null_staffname)}")

# Optionally, display the rows (can limit to first few)
print("\nRows with missing DoctorID:")
print(null_doctorid.head())

print("\nRows with missing Staff_name:")
print(null_staffname.head())
# Out:
# Number of rows with missing DoctorID: 0
# Number of rows with missing Staff_name: 0
#
# Rows with missing DoctorID:
# Empty DataFrame
# Columns: [ShortName, OrganizationKey, Staff_name, DoctorID, Specialty, Specialty_Key, DoctorClinicID, StartDate_DailyClinic, EndDate_DailyClinic, ActualStartTime, ActualEndTime, No_of_Clinic, ActualWorkingHours, Sub_Specialty]
# Index: []
#
# Rows with missing Staff_name:
# Empty DataFrame
# Columns: [ShortName, OrganizationKey, Staff_name, DoctorID, Specialty, Specialty_Key, DoctorClinicID, StartDate_DailyClinic, EndDate_DailyClinic, ActualStartTime, ActualEndTime, No_of_Clinic, ActualWorkingHours, Sub_Specialty]
# Index: []

# %%
row = df[df['DoctorID'] == '11_378']
print(row)
# Out:
#       ShortName  OrganizationKey Staff_name DoctorID Specialty Specialty_Key  \
# 18659       HJH                1        NaN   11_378       NaN           NaN
#
#        DoctorClinicID         StartDate_DailyClinic  \
# 18659         1107035 1970-01-01 00:00:00.020240822
#
#                 EndDate_DailyClinic ActualStartTime   ActualEndTime  \
# 18659 1970-01-01 00:00:00.020240822 0 days 09:00:00 0 days 17:00:00
#
#        No_of_Clinic  ActualWorkingHours Sub_Specialty
# 18659             1                 8.0           NaN

# %%
ids_to_drop = ['11_308', '11_310','11_311', '11_656','11_378','11_309']
df = df[~df['DoctorID'].isin(ids_to_drop)].reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# ShortName                   0
# OrganizationKey             0
# Staff_name                  0
# DoctorID                    0
# Specialty                   0
# Specialty_Key             348
# DoctorClinicID              0
# StartDate_DailyClinic       0
# EndDate_DailyClinic         0
# ActualStartTime             0
# ActualEndTime               0
# No_of_Clinic                0
# ActualWorkingHours          0
# Sub_Specialty            1719
# dtype: int64

# %%
print(df['Staff_name'].unique())
# Out:
# ['Hatem Hemdan Elalwanii' 'Raghda Abdelhamid Okda'
#  'Thowaiba Ahmed Eltayeb Mohammed' 'Dalenda Mohamed Alarfaoui'
#  'Elsayed Ibrahim M. Shaheen' 'Ameer Abdulhai Abdulkarim Sayed'
#  'Osama Ahmed Mohamed Abdelsalam' 'Rehab Wageh Elsayed Zain'
#  'Ahmed Mohmoud Koheil' 'Ramy Atef Ibrahim Abdelhamid'
#  'Yasmin Ibrahim Abdelwahed Ahmed' 'Mohsen Mohamed Abdelhady Mohamed'
#  'Sara Mohamed Said Soliman' 'Ahmed Ibrhim Salman'
#  'Lamiaa Mahmoud Nasr Elkinani' 'Samar Mohamed Neddal Sawas'
#  'Ibrahim Ali Ibrahim Abdelmonem' 'Ameen Ahmed Alsaggaf'
#  'Ahmad Jaber Jaber' 'Walaa Ahmed Ibrahim Elsadany' 'Wael Ziyad Hashim'
#  'Asmaa Gomah Yousf Abdelmenem' 'Mahmoud Ahmed Hussein Gehad'
#  'Adel Ali Aljawhari' 'Beauty Clinic' 'Osama Elsayed Bekhit'
#  'Bashayr Ghurmullah Sultan Alamri' 'Rayan Adel Ahmed Hafiz'
#  'Sarah Mahmoud Aly Amer' 'Ehab Abdulsamad Mohamed' 'Safa El Said'
#  'Yara Ahmed Elmaghraby' 'Ahmed Ali A. Elsayed'
# ...

# %%
print(df['Specialty'].unique())
# Out:
# ['Internal Medicine' 'Dental Services' 'Orthopedics' 'Neurology'
#  'Neuro Surgery' 'Urology' 'Pediatrics' 'Developmental Disorders'
#  'OBE & GYN' 'Cardiology' 'Ophthalmology' 'General Surgery' 'Dermatology'
#  'Plastic Surgery' 'Speech and Phonetics' 'Chest' 'Family Medicine'
#  'Vascular Surgery' 'Other' 'Physiotherapy' 'Psychology'
#  'emergency medicine' 'Andrology' 'Nutrition' 'Oncology' 'Activities'
#  'Ward Services' 'Audiological medicine' 'IT OFFICER'
#  'ASST.CSSD TECHNICIAN' 'Occupational therapy (OT)' 'E.N.T.'
#  'JR. MARKETING SPECIALIST' 'CHEF COOK' 'WARD NURSE' 'Prosthodontics'
#  'TELEPHONE OPERATOR' 'Endodontic and cosmetic dentistry'
#  'JONIOR RECEPTIONIST' 'KITCHEN WORKER' 'CUSTOMER SERVICE OFFICER'
#  'COOKER ASSISSTANT' 'Rheumatology' 'MEDICAL RECORD WORKER'
#  'CATERING MANAGER' 'Radiology' 'SECURITY GUARD' 'Neuropsychiatry'
#  'WAITER' 'HEAD NURSE' 'JR. PERSONNEL OFFICER' 'PATIENT ACCESS AGENT'
#  'WORKER' 'Assessment' 'Pharmacy Services' 'Cardiothoracic'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108715 entries, 0 to 108714
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ShortName              108715 non-null  object
#  1   OrganizationKey        108715 non-null  int64
#  2   Staff_name             108381 non-null  object
#  3   DoctorID               108392 non-null  object
#  4   Specialty              108381 non-null  object
#  5   Specialty_Key          108033 non-null  object
#  6   DoctorClinicID         108715 non-null  int64
#  7   StartDate_DailyClinic  108715 non-null  int64
#  8   EndDate_DailyClinic    108715 non-null  int64
#  9   ActualStartTime        108715 non-null  object
#  10  ActualEndTime          108715 non-null  object
#  11  No_of_Clinic           108715 non-null  int64
#  12  ActualWorkingHours     108715 non-null  float64
#  13  Sub_Specialty          106662 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(df['ShortName'].unique())
# Out:
# ['HJH' 'MKR' 'SNB' 'AKW' 'ALW' 'LCH']

# %%
df['Specialty'] = df['Specialty'].astype(str).str.lower()

# %%
df['Specialty'] = df['Specialty'].replace({
    'pharmacy services': 'pharmacy',
    'emergency services': 'emergency',
    'pediatric neurology': 'pediatrics neurology',
    'endodontic': 'endodontics'
})

# %%
df['Specialty'].unique()
# Out:
# array(['internal medicine', 'dental services', 'orthopedics', 'neurology',
#        'neuro surgery', 'urology', 'pediatrics',
#        'developmental disorders', 'obe & gyn', 'cardiology',
#        'ophthalmology', 'general surgery', 'dermatology',
#        'plastic surgery', 'speech and phonetics', 'chest',
#        'family medicine', 'vascular surgery', 'other', 'physiotherapy',
#        'psychology', 'emergency medicine', 'andrology', 'nutrition',
#        'oncology', 'activities', 'ward services', 'audiological medicine',
#        'it officer', 'asst.cssd technician', 'occupational therapy (ot)',
#        'e.n.t.', 'jr. marketing specialist', 'chef cook', 'ward nurse',
#        'prosthodontics', 'telephone operator',
#        'endodontic and cosmetic dentistry', 'jonior receptionist',
#        'kitchen worker', 'customer service officer', 'cooker assisstant',
#        'rheumatology', 'medical record worker', 'catering manager',
# ...

# %% [markdown]
# # Data Visualization(EDA)

# %%
df['Date']=df['EndDate_DailyClinic']-df['StartDate_DailyClinic']
df['Time']=df['ActualEndTime']-df['ActualStartTime']

# %%
df['Date'].max()
# Out:
# Timedelta('0 days 00:00:00')

# %%
df['Time'].max()
# Out:
# Timedelta('0 days 23:59:00')

# %%
# أولاً: نتأكد من تنسيق الوقت
df['ActualStartTime'] = df['ActualStartTime'].astype(str).str.extract(r'(\d{2}:\d{2}:\d{2})')
df['ActualEndTime'] = df['ActualEndTime'].astype(str).str.extract(r'(\d{2}:\d{2}:\d{2})')

# ثانياً: ندمج التاريخ مع الوقت
df['Start_Clinic_DateTime'] = pd.to_datetime(df['StartDate_DailyClinic'].astype(str) + ' ' + df['ActualStartTime'])
df['End_Clinic_DateTime'] = pd.to_datetime(df['EndDate_DailyClinic'].astype(str) + ' ' + df['ActualEndTime'])

# ثالثاً: نحسب ساعات العمل الفعلية
df['ActualWorkingHours'] = df['End_Clinic_DateTime'] - df['Start_Clinic_DateTime']
# Out:
# C:\Users\miran\AppData\Local\Temp\ipykernel_32940\688846972.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Start_Clinic_DateTime'] = pd.to_datetime(df['StartDate_DailyClinic'].astype(str) + ' ' + df['ActualStartTime'])
# C:\Users\miran\AppData\Local\Temp\ipykernel_32940\688846972.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['End_Clinic_DateTime'] = pd.to_datetime(df['EndDate_DailyClinic'].astype(str) + ' ' + df['ActualEndTime'])

# %%
df.head()
# Out:
#   ShortName  OrganizationKey                       Staff_name DoctorID  \
# 0       HJH                1           Hatem Hemdan Elalwanii   1_9746
# 1       HJH                1           Raghda Abdelhamid Okda   1_9864
# 2       HJH                1  Thowaiba Ahmed Eltayeb Mohammed  1_10960
# 3       HJH                1        Dalenda Mohamed Alarfaoui   1_9906
# 4       HJH                1       Elsayed Ibrahim M. Shaheen   1_4946
#
#            Specialty Specialty_Key     DoctorClinicID  \
# 0  Internal Medicine          1_11   3306974620231029
# 1    Dental Services           1_4   3304986420240301
# 2  Internal Medicine          1_11  32091096020210711
# 3  Internal Medicine          1_11   3287990620230710
# 4        Orthopedics          1_21   1131494620211224
#
#           StartDate_DailyClinic           EndDate_DailyClinic ActualStartTime  \
# 0 1970-01-01 00:00:00.020241031 1970-01-01 00:00:00.020241031        16:39:00
# ...

# %%
df['ActualWorkingHours'].iloc[]
# Out:
# Timedelta('0 days 23:59:00')

# %%
row = df[df['ActualWorkingHours'] == '0 days 23:59:00']
print(row)
# Out:
#        ShortName  OrganizationKey                Staff_name DoctorID  \
# 3216         HJH                1      Andalusia Laboratory   11_380
# 3828         HJH                1      Andalusia Laboratory   11_380
# 5285         SNB                9         Lab Clinic Doctor    9_218
# 8084         HJH                1      Andalusia Laboratory   11_380
# 13749        HJH                1      Andalusia Laboratory   11_380
# 13857        HJH                1      Andalusia Laboratory   11_380
# 15673        HJH                1      Andalusia Laboratory   11_380
# 16722        HJH                1      Andalusia Laboratory   11_380
# 17107        HJH                1      Andalusia Laboratory   11_380
# 20583        SNB                9         Lab Clinic Doctor    9_218
# 20905        HJH                1      Andalusia Laboratory   11_380
# 28217        SNB                9  Ultrasound Clinic Doctor    9_181
# 28901        SNB                9         Lab Clinic Doctor    9_218
# ...

# %%
df.loc[3216]
# Out:
# ShortName                                          HJH
# OrganizationKey                                      1
# Staff_name                        Andalusia Laboratory
# DoctorID                                        11_380
# Specialty                                        Other
# Specialty_Key                                    11_79
# DoctorClinicID                                 1103611
# StartDate_DailyClinic    1970-01-01 00:00:00.020241207
# EndDate_DailyClinic      1970-01-01 00:00:00.020241207
# ActualStartTime                               00:00:00
# ActualEndTime                                 23:59:00
# No_of_Clinic                                         1
# ActualWorkingHours                     0 days 23:59:00
# Sub_Specialty                               Laboratory
# Date                                   0 days 00:00:00
# Time                                   0 days 23:59:00
# Start_Clinic_DateTime              1970-01-01 00:00:00
# ...

# %%
df[df['Staff_name'] == 'Andalusia Laboratory']
# Out:
#        ShortName  OrganizationKey            Staff_name DoctorID Specialty  \
# 3216         HJH                1  Andalusia Laboratory   11_380     Other
# 3828         HJH                1  Andalusia Laboratory   11_380     Other
# 8084         HJH                1  Andalusia Laboratory   11_380     Other
# 13749        HJH                1  Andalusia Laboratory   11_380     Other
# 13857        HJH                1  Andalusia Laboratory   11_380     Other
# 15673        HJH                1  Andalusia Laboratory   11_380     Other
# 16722        HJH                1  Andalusia Laboratory   11_380     Other
# 17107        HJH                1  Andalusia Laboratory   11_380     Other
# 20905        HJH                1  Andalusia Laboratory   11_380     Other
# 35465        HJH                1  Andalusia Laboratory   11_380     Other
# 40544        HJH                1  Andalusia Laboratory   11_380     Other
# ...

# %%
# List of DoctorIDs where you want to apply the replacement
target_ids = ['11_380','9_180','9_218']  # You can add more if needed

# Replace 'Other' with 'Lab' in Specialty column, only for target IDs
df.loc[df['DoctorID'].isin(target_ids) & (df['Specialty'] == 'Other'), 'Specialty'] = 'Lab'

# %%
df[df['Staff_name'] == 'Andalusia Laboratory']
# Out:
#        ShortName  OrganizationKey            Staff_name DoctorID Specialty  \
# 3216         HJH                1  Andalusia Laboratory   11_380       Lab
# 3828         HJH                1  Andalusia Laboratory   11_380       Lab
# 8084         HJH                1  Andalusia Laboratory   11_380       Lab
# 13749        HJH                1  Andalusia Laboratory   11_380       Lab
# 13857        HJH                1  Andalusia Laboratory   11_380       Lab
# 15673        HJH                1  Andalusia Laboratory   11_380       Lab
# 16722        HJH                1  Andalusia Laboratory   11_380       Lab
# 17107        HJH                1  Andalusia Laboratory   11_380       Lab
# 20905        HJH                1  Andalusia Laboratory   11_380       Lab
# 35465        HJH                1  Andalusia Laboratory   11_380       Lab
# 40544        HJH                1  Andalusia Laboratory   11_380       Lab
# ...

# %%
ts = df['ActualWorkingHours'].dt.total_seconds() / 3600  # convert timedelta to hours

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(ts.dropna())

print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -131.11354059286546
# p-value: 0.0

# %%
df['DateTime'] = pd.to_datetime(df['StartDate_DailyClinic'])  # or your correct date column
df.set_index('DateTime', inplace=True)

# %%
# Convert to hours
df['ActualWorkingHours_Hours'] = df['ActualWorkingHours'].dt.total_seconds() / 3600

# Group by month and clinic
clinic_ts = df.groupby([pd.Grouper(freq='M'), 'Specialty'])['ActualWorkingHours_Hours'].sum().unstack()

# %%
# First, group by date and speciality, count occurrences
df_grouped = df.groupby(['ActualWorkingHours', 'Specialty']).size().unstack(fill_value=0)

# Now plot
df_grouped.plot(figsize=(10,6))
plt.xlabel("Date")
plt.ylabel("Count of Records")
plt.title("Number of Records per Specialty Over Time")
plt.legend(title="Specialty", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()
plt.show()

# %%
df[df['Specialty'] == 'Other']
# Out:
#        ShortName  OrganizationKey                       Staff_name DoctorID  \
# 58           HJH                1                    Ex Anesthesia   1_2003
# 125          SNB                9            Snb Assessment Doctor    9_311
# 163          SNB                9            Snb Assessment Doctor    9_311
# 174          ALW               13                          Iv Room   13_161
# 202          ALW               13                          Iv Room   13_161
# ...          ...              ...                              ...      ...
# 108211       HJH                1   MANSOUR GWAINM GANAM AL-SOLAMI    1_665
# 108247       SNB                9    Ali Mohamed Abdelhady Elhabet    9_108
# 108294       HJH                1                      Iqama Cons.   1_4043
# 108297       SNB                9    Ali Mohamed Abdelhady Elhabet    9_108
# 108358       SNB                9  Walaa Ramadan Abd Elsalhin Saad   4_3470
#
#        Specialty Specialty_Key    DoctorClinicID  \
# ...
